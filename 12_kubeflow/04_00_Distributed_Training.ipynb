# %% [markdown]
# # What is Distributed Training
# Deep learning has shown that being able to train large models on vasts amount of data can drastically improve model performance.
#
# However, consider the problem of training a deep network with millions, or even billions of parameters. How do we achieve this without waiting for days, or even multiple weeks? Dean et al propose a different training paradigm which allows us to train and serve a model on multiple physical machines. The auth|ors propose two novel methodologies to accomplish this, namely, `model parallelism` and `data parallelism`.
#
#
# # Model Parallelism
# When a big model can not fit into a single node's memory, model parallel training can be employed to handle the big model. Model parallelism training has two key features:
# 1. Each worker task is responsible for estimating different part of the model parameters. So the computation logic in each worker is different from other one else.
# 2. There is application-level data communication between workers.
#
# ![Model Parallelism](./images/model_parallelism.jpg)
#
#
# # Data Parallelism
#
# The algorithm distributes the data between various tasks.
# 1. Each worker task is responsible for estimating different part of the dataset
# 2. Tasks then exchange their estimate(s) with each other to come up with the right estimate for the step.
#
# ![Data Parallelism](./images/data_parallelism.png)

# %% [markdown]
# # Distributed Training in Tensorflow
# "Data Parallelism" is the most common training configuration, it involves multiple tasks in a `worker` job training the same model on different mini-batches of data, updating shared parameters hosted in one or more tasks in a `ps` (parameter server) job. All tasks typically run on different machines or containers. There are many ways to specify this structure in TensorFlow, and Tensorflow team are building libraries that will simplify the work of specifying a replicated model. Other platforms like `MXnet`, `Petuum` also have the same abstraction.
#
# - __In-graph replication__. In this approach, the client builds a single tf.Graph that contains one set of parameters (in tf.Variable nodes pinned to /job:ps); and multiple copies of the compute-intensive part of the model, each pinned to a different task in /job:worker.
#
# - __Between-graph replication__. In this approach, there is a separate client for each /job:worker task, typically in the same process as the worker task. Each client builds a similar graph containing the parameters (pinned to /job:ps as before using tf.train.replica_device_setter to map them deterministically to the same tasks); and a single copy of the compute-intensive part of the model, pinned to the local task in /job:worker.
#
# - __Asynchronous training__. In this approach, each replica of the graph has an independent training loop that executes without coordination. It is compatible with both forms of replication above.
#
# - __Synchronous training__. In this approach, all of the replicas read the same values for the current parameters, compute gradients in parallel, and then apply them together. It is compatible with in-graph replication (e.g. using gradient averaging as in the CIFAR-10 multi-GPU trainer), and between-graph replication (e.g. using the tf.train.SyncReplicasOptimizer).

# %% [markdown]
# # Examples
#
# We will introduce two frameworks in the distributed training. Tensorflow and PyTorch

# %% [markdown]
# # View Distributed TensorFlow Job (TFJob) Definition

# %%
# !cat ./distributed-training-jobs/distributed-tensorflow-job.yaml
# Out:
# apiVersion: "kubeflow.org/v1"
# kind: "TFJob"
# metadata:
#   name: "distributed-tensorflow-job"
# spec:
#   tfReplicaSpecs:
#     PS:
#       replicas: 2
#       restartPolicy: Never
#       template:
#         metadata:
#           annotations:
#             sidecar.istio.io/inject: "false"
#         spec:
#           containers:
#             - name: tensorflow
#               image: gcr.io/kubeflow-ci/tf-dist-mnist-test:1.0
#     Worker:
#       replicas: 4
#       restartPolicy: Never
#       template:
#         metadata:
#           annotations:
#             sidecar.istio.io/inject: "false"
#         spec:
#           containers:
#             - name: tensorflow
#               image: gcr.io/kubeflow-ci/tf-dist-mnist-test:1.0

# %% [markdown]
# # Launch Distributed TensorFlow Training job (`TFJob`)

# %%
# !kubectl create -f distributed-training-jobs/distributed-tensorflow-job.yaml
# Out:
# tfjob.kubeflow.org/distributed-tensorflow-job created

# %% [markdown]
# # View All TFJobs

# %%
# !kubectl get tfjob
# Out:
# NAME                         STATE   AGE
# distributed-tensorflow-job           1s

# %% [markdown]
# # Check TFJob Status

# %%
# !kubectl describe tfjob distributed-tensorflow-job
# Out:
# Name:         distributed-tensorflow-job
# Namespace:    anonymous
# Labels:       <none>
# Annotations:  <none>
# API Version:  kubeflow.org/v1
# Kind:         TFJob
# Metadata:
#   Creation Timestamp:  2020-08-23T01:05:31Z
#   Generation:          1
#   Resource Version:    63010
#   Self Link:           /apis/kubeflow.org/v1/namespaces/anonymous/tfjobs/distributed-tensorflow-job
#   UID:                 c8ec2343-8022-4f17-9582-8bb53d52de44
# Spec:
#   Tf Replica Specs:
#     PS:
#       Replicas:        2
#       Restart Policy:  Never
#       Template:
#         Metadata:
#           Annotations:
#             sidecar.istio.io/inject:  false
#         Spec:
#           Containers:
#             Image:  gcr.io/kubeflow-ci/tf-dist-mnist-test:1.0
#             Name:   tensorflow
#     Worker:
#       Replicas:        4
#       Restart Policy:  Never
#       Template:
#         Metadata:
#           Annotations:
#             sidecar.istio.io/inject:  false
#         Spec:
#           Containers:
#             Image:  gcr.io/kubeflow-ci/tf-dist-mnist-test:1.0
#             Name:   tensorflow
# Events:
#   Type    Reason                   Age   From         Message
#   ----    ------                   ----  ----         -------
#   Normal  SuccessfulCreatePod      1s    tf-operator  Created pod: distributed-tensorflow-job-ps-0
#   Normal  SuccessfulCreatePod      1s    tf-operator  Created pod: distributed-tensorflow-job-ps-1
#   Normal  SuccessfulCreateService  1s    tf-operator  Created service: distributed-tensorflow-job-ps-0
#   Normal  SuccessfulCreateService  1s    tf-operator  Created service: distributed-tensorflow-job-ps-1
#   Normal  SuccessfulCreatePod      1s    tf-operator  Created pod: distributed-tensorflow-job-worker-0
#   Normal  SuccessfulCreatePod      0s    tf-operator  Created pod: distributed-tensorflow-job-worker-1
#   Normal  SuccessfulCreatePod      0s    tf-operator  Created pod: distributed-tensorflow-job-worker-2

# %% [markdown]
# # Check Distributed TensorFlow Training Logs
# _Note:  If you see an error in this cell, just wait a bit and re-run to see the logs._

# %%
# !kubectl get pod | grep distributed-tensorflow-job
# Out:
# distributed-tensorflow-job-ps-0       0/1     ContainerCreating   0          2s
# distributed-tensorflow-job-ps-1       0/1     ContainerCreating   0          2s
# distributed-tensorflow-job-worker-0   0/1     ContainerCreating   0          2s
# distributed-tensorflow-job-worker-1   0/1     ContainerCreating   0          1s
# distributed-tensorflow-job-worker-2   0/1     ContainerCreating   0          1s
# distributed-tensorflow-job-worker-3   0/1     ContainerCreating   0          1s

# %%
# !kubectl logs distributed-tensorflow-job-worker-0
# Out:
# /usr/local/lib/python2.7/dist-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# 2020-08-23 01:05:53.696926: I tensorflow/core/platform/cpu_feature_guard.cc:137] Your CPU supports instructions that this TensorFlow binary was not compiled to use: SSE4.1 SSE4.2 AVX AVX2 AVX512F FMA
# 2020-08-23 01:05:53.697635: I tensorflow/core/distributed_runtime/rpc/grpc_channel.cc:215] Initialize GrpcChannelCache for job ps -> {0 -> distributed-tensorflow-job-ps-0.anonymous.svc:2222, 1 -> distributed-tensorflow-job-ps-1.anonymous.svc:2222}
# 2020-08-23 01:05:53.697657: I tensorflow/core/distributed_runtime/rpc/grpc_channel.cc:215] Initialize GrpcChannelCache for job worker -> {0 -> localhost:2222, 1 -> distributed-tensorflow-job-worker-1.anonymous.svc:2222, 2 -> distributed-tensorflow-job-worker-2.anonymous.svc:2222, 3 -> distributed-tensorflow-job-worker-3.anonymous.svc:2222}
# 2020-08-23 01:05:53.697947: I tensorflow/core/distributed_runtime/rpc/grpc_server_lib.cc:324] Started server with target: grpc://localhost:2222
# WARNING:tensorflow:From /var/tf_dist_mnist/dist_mnist.py:239: __init__ (from tensorflow.python.training.supervisor) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please switch to tf.train.MonitoredTrainingSession
# 2020-08-23 01:05:54.436442: I tensorflow/core/distributed_runtime/master_session.cc:1017] Start master session 588cc2bc4ca587c9 with config: device_filters: "/job:ps" device_filters: "/job:worker/task:0" allow_soft_placement: true
# Successfully downloaded train-images-idx3-ubyte.gz 9912422 bytes.
# Extracting /tmp/mnist-data/train-images-idx3-ubyte.gz
# Successfully downloaded train-labels-idx1-ubyte.gz 28881 bytes.
# Extracting /tmp/mnist-data/train-labels-idx1-ubyte.gz
# Successfully downloaded t10k-images-idx3-ubyte.gz 1648877 bytes.
# Extracting /tmp/mnist-data/t10k-images-idx3-ubyte.gz
# Successfully downloaded t10k-labels-idx1-ubyte.gz 4542 bytes.
# Extracting /tmp/mnist-data/t10k-labels-idx1-ubyte.gz
# job name = worker
# task index = 0
# Worker 0: Initializing session...
# Worker 0: Session initialization complete.
# Training begins @ 1598144754.757005
# 1598144755.262128: Worker 0: training step 1 done (global step: 27)
# 1598144755.283756: Worker 0: training step 2 done (global step: 31)
# 1598144755.310473: Worker 0: training step 3 done (global step: 36)
# 1598144755.341225: Worker 0: training step 4 done (global step: 38)
# 1598144755.365911: Worker 0: training step 5 done (global step: 43)
# 1598144755.395247: Worker 0: training step 6 done (global step: 45)
# 1598144755.424138: Worker 0: training step 7 done (global step: 49)
# 1598144755.458729: Worker 0: training step 8 done (global step: 54)
# 1598144755.521664: Worker 0: training step 9 done (global step: 59)
# 1598144755.581600: Worker 0: training step 10 done (global step: 63)
# 1598144755.608727: Worker 0: training step 11 done (global step: 67)
# 1598144755.618764: Worker 0: training step 12 done (global step: 73)
# 1598144755.636170: Worker 0: training step 13 done (global step: 76)
# 1598144755.659371: Worker 0: training step 14 done (global step: 80)
# 1598144755.677078: Worker 0: training step 15 done (global step: 87)
# 1598144755.698278: Worker 0: training step 16 done (global step: 91)
# 1598144755.719614: Worker 0: training step 17 done (global step: 95)
# 1598144755.740193: Worker 0: training step 18 done (global step: 100)
# 1598144755.758772: Worker 0: training step 19 done (global step: 106)
# 1598144755.775944: Worker 0: training step 20 done (global step: 109)
# 1598144755.795072: Worker 0: training step 21 done (global step: 112)
# 1598144755.816004: Worker 0: training step 22 done (global step: 117)
# 1598144755.830902: Worker 0: training step 23 done (global step: 122)
# 1598144755.862341: Worker 0: training step 24 done (global step: 127)
# 1598144755.879884: Worker 0: training step 25 done (global step: 132)
# 1598144755.903696: Worker 0: training step 26 done (global step: 136)
# 1598144755.918309: Worker 0: training step 27 done (global step: 140)
# 1598144755.946283: Worker 0: training step 28 done (global step: 145)
# 1598144755.971286: Worker 0: training step 29 done (global step: 149)
# 1598144755.993243: Worker 0: training step 30 done (global step: 155)
# 1598144756.012684: Worker 0: training step 31 done (global step: 161)
# 1598144756.027479: Worker 0: training step 32 done (global step: 165)
# 1598144756.037419: Worker 0: training step 33 done (global step: 171)
# 1598144756.051346: Worker 0: training step 34 done (global step: 174)
# 1598144756.068226: Worker 0: training step 35 done (global step: 179)
# 1598144756.093711: Worker 0: training step 36 done (global step: 184)
# 1598144756.115980: Worker 0: training step 37 done (global step: 190)
# 1598144756.139542: Worker 0: training step 38 done (global step: 193)
# 1598144756.159833: Worker 0: training step 39 done (global step: 199)
# 1598144756.188405: Worker 0: training step 40 done (global step: 203)
# 1598144756.218031: Worker 0: training step 41 done (global step: 206)
# 1598144756.240182: Worker 0: training step 42 done (global step: 213)
# 1598144756.258303: Worker 0: training step 43 done (global step: 217)
# 1598144756.289557: Worker 0: training step 44 done (global step: 221)
# 1598144756.302568: Worker 0: training step 45 done (global step: 227)
# 1598144756.330704: Worker 0: training step 46 done (global step: 229)
# 1598144756.349835: Worker 0: training step 47 done (global step: 233)
# 1598144757.354191: Worker 0: training step 98 done (global step: 458)
# 1598144757.371589: Worker 0: training step 99 done (global step: 464)
# 1598144757.401227: Worker 0: training step 100 done (global step: 468)
# 1598144757.420038: Worker 0: training step 101 done (global step: 471)
# 1598144757.441074: Worker 0: training step 102 done (global step: 475)
# 1598144757.458269: Worker 0: training step 103 done (global step: 479)
# 1598144757.482843: Worker 0: training step 104 done (global step: 483)
# 1598144757.504573: Worker 0: training step 105 done (global step: 487)
# 1598144757.524441: Worker 0: training step 106 done (global step: 489)
# 1598144757.539719: Worker 0: training step 107 done (global step: 494)
# 1598144757.566716: Worker 0: training step 108 done (global step: 497)
# 1598144757.586006: Worker 0: training step 109 done (global step: 501)
# 1598144757.609049: Worker 0: training step 110 done (global step: 505)
# 1598144757.627791: Worker 0: training step 111 done (global step: 508)
# 1598144757.641959: Worker 0: training step 112 done (global step: 511)
# 1598144757.653828: Worker 0: training step 113 done (global step: 516)
# 1598144757.675453: Worker 0: training step 114 done (global step: 520)
# 1598144757.699634: Worker 0: training step 115 done (global step: 523)
# 1598144757.719523: Worker 0: training step 116 done (global step: 527)
# 1598144757.737085: Worker 0: training step 117 done (global step: 530)
# 1598144757.755952: Worker 0: training step 118 done (global step: 535)
# 1598144757.772199: Worker 0: training step 119 done (global step: 540)
# 1598144757.786771: Worker 0: training step 120 done (global step: 544)
# 1598144757.812429: Worker 0: training step 121 done (global step: 549)
# 1598144757.840827: Worker 0: training step 122 done (global step: 552)
# 1598144757.879505: Worker 0: training step 123 done (global step: 556)
# 1598144757.892667: Worker 0: training step 124 done (global step: 562)
# 1598144757.912933: Worker 0: training step 125 done (global step: 566)
# 1598144757.943032: Worker 0: training step 126 done (global step: 569)
# 1598144757.964726: Worker 0: training step 127 done (global step: 574)
# 1598144757.993232: Worker 0: training step 128 done (global step: 578)
# 1598144758.029564: Worker 0: training step 129 done (global step: 579)
# 1598144758.059872: Worker 0: training step 130 done (global step: 586)
# 1598144758.093741: Worker 0: training step 131 done (global step: 591)
# 1598144758.118625: Worker 0: training step 132 done (global step: 597)
# 1598144758.142351: Worker 0: training step 133 done (global step: 599)
# 1598144758.170436: Worker 0: training step 134 done (global step: 603)
# 1598144758.184461: Worker 0: training step 135 done (global step: 608)
# 1598144758.205490: Worker 0: training step 136 done (global step: 613)
# 1598144758.218635: Worker 0: training step 137 done (global step: 617)
# 1598144758.248736: Worker 0: training step 138 done (global step: 621)
# 1598144758.269733: Worker 0: training step 139 done (global step: 625)
# 1598144758.294571: Worker 0: training step 140 done (global step: 629)
# 1598144758.320406: Worker 0: training step 141 done (global step: 633)
# 1598144758.341558: Worker 0: training step 142 done (global step: 638)
# 1598144758.360672: Worker 0: training step 143 done (global step: 639)
# 1598144758.376411: Worker 0: training step 144 done (global step: 644)
# 1598144758.387184: Worker 0: training step 145 done (global step: 649)
# 1598144758.401867: Worker 0: training step 146 done (global step: 653)
# 1598144758.411913: Worker 0: training step 147 done (global step: 658)
# 1598144758.423931: Worker 0: training step 148 done (global step: 661)
# 1598144758.431517: Worker 0: training step 149 done (global step: 666)
# 1598144758.440009: Worker 0: training step 150 done (global step: 668)
# 1598144758.457767: Worker 0: training step 151 done (global step: 672)
# 1598144758.472522: Worker 0: training step 152 done (global step: 679)
# 1598144758.481918: Worker 0: training step 153 done (global step: 684)
# 1598144758.495374: Worker 0: training step 154 done (global step: 686)
# 1598144758.509283: Worker 0: training step 155 done (global step: 692)
# 1598144758.523538: Worker 0: training step 156 done (global step: 696)
# 1598144758.535481: Worker 0: training step 157 done (global step: 702)
# 1598144758.545963: Worker 0: training step 158 done (global step: 706)
# 1598144758.563110: Worker 0: training step 159 done (global step: 711)
# 1598144758.574298: Worker 0: training step 160 done (global step: 717)
# 1598144758.600376: Worker 0: training step 161 done (global step: 722)
# 1598144758.613156: Worker 0: training step 162 done (global step: 728)
# 1598144758.624918: Worker 0: training step 163 done (global step: 730)
# 1598144758.641418: Worker 0: training step 164 done (global step: 736)
# 1598144758.656911: Worker 0: training step 165 done (global step: 740)
# 1598144758.672485: Worker 0: training step 166 done (global step: 744)
# 1598144758.685250: Worker 0: training step 167 done (global step: 748)
# 1598144758.699490: Worker 0: training step 168 done (global step: 752)
# 1598144758.715515: Worker 0: training step 169 done (global step: 754)
# 1598144758.731438: Worker 0: training step 170 done (global step: 759)
# 1598144758.744468: Worker 0: training step 171 done (global step: 765)
# 1598144758.761241: Worker 0: training step 172 done (global step: 770)
# 1598144758.774828: Worker 0: training step 173 done (global step: 774)
# 1598144758.789925: Worker 0: training step 174 done (global step: 777)
# 1598144758.806485: Worker 0: training step 175 done (global step: 781)
# 1598144758.839441: Worker 0: training step 176 done (global step: 786)
# 1598144758.849391: Worker 0: training step 177 done (global step: 790)
# 1598144758.859587: Worker 0: training step 178 done (global step: 794)
# 1598144758.873868: Worker 0: training step 179 done (global step: 798)
# 1598144758.888420: Worker 0: training step 180 done (global step: 804)
# 1598144758.900290: Worker 0: training step 181 done (global step: 810)
# 1598144758.914390: Worker 0: training step 182 done (global step: 814)
# 1598144758.928225: Worker 0: training step 183 done (global step: 818)
# 1598144758.939228: Worker 0: training step 184 done (global step: 821)
# 1598144758.954393: Worker 0: training step 185 done (global step: 824)
# 1598144758.968322: Worker 0: training step 186 done (global step: 830)
# 1598144758.986733: Worker 0: training step 187 done (global step: 834)
# 1598144758.998151: Worker 0: training step 188 done (global step: 837)
# 1598144759.011007: Worker 0: training step 189 done (global step: 841)
# 1598144759.025205: Worker 0: training step 190 done (global step: 845)
# 1598144759.040439: Worker 0: training step 191 done (global step: 851)
# 1598144759.049340: Worker 0: training step 192 done (global step: 856)
# 1598144759.064120: Worker 0: training step 193 done (global step: 860)
# 1598144759.076322: Worker 0: training step 194 done (global step: 864)
# 1598144759.086250: Worker 0: training step 195 done (global step: 871)
# 1598144759.103405: Worker 0: training step 196 done (global step: 873)
# 1598144759.114288: Worker 0: training step 197 done (global step: 880)
# 1598144759.129015: Worker 0: training step 198 done (global step: 884)
# 1598144766.403788: Worker 0: training step 589 done (global step: 2641)
# 1598144766.419328: Worker 0: training step 590 done (global step: 2643)
# 1598144766.444407: Worker 0: training step 591 done (global step: 2647)
# 1598144766.467744: Worker 0: training step 592 done (global step: 2651)
# 1598144766.486883: Worker 0: training step 593 done (global step: 2655)
# 1598144766.520749: Worker 0: training step 594 done (global step: 2659)
# 1598144766.545267: Worker 0: training step 595 done (global step: 2664)
# 1598144766.567606: Worker 0: training step 596 done (global step: 2669)
# 1598144766.586597: Worker 0: training step 597 done (global step: 2674)
# 1598144766.600768: Worker 0: training step 598 done (global step: 2678)
# 1598144766.617387: Worker 0: training step 599 done (global step: 2683)
# 1598144766.635356: Worker 0: training step 600 done (global step: 2688)
# 1598144766.655036: Worker 0: training step 601 done (global step: 2692)
# 1598144766.671919: Worker 0: training step 602 done (global step: 2696)
# 1598144766.687000: Worker 0: training step 603 done (global step: 2700)
# 1598144766.712229: Worker 0: training step 604 done (global step: 2704)
# 1598144766.744609: Worker 0: training step 605 done (global step: 2711)
# 1598144766.775215: Worker 0: training step 606 done (global step: 2718)
# 1598144766.795254: Worker 0: training step 607 done (global step: 2722)
# 1598144766.848457: Worker 0: training step 608 done (global step: 2725)
# 1598144766.875514: Worker 0: training step 609 done (global step: 2732)
# 1598144766.889911: Worker 0: training step 610 done (global step: 2737)
# 1598144766.907976: Worker 0: training step 611 done (global step: 2741)
# 1598144766.935113: Worker 0: training step 612 done (global step: 2744)
# 1598144766.957135: Worker 0: training step 613 done (global step: 2750)
# 1598144766.972893: Worker 0: training step 614 done (global step: 2755)
# 1598144766.989385: Worker 0: training step 615 done (global step: 2758)
# 1598144767.002955: Worker 0: training step 616 done (global step: 2762)
# 1598144767.025775: Worker 0: training step 617 done (global step: 2764)
# 1598144767.041960: Worker 0: training step 618 done (global step: 2770)
# 1598144767.059463: Worker 0: training step 619 done (global step: 2773)
# 1598144767.069516: Worker 0: training step 620 done (global step: 2780)
# 1598144767.082086: Worker 0: training step 621 done (global step: 2782)
# 1598144767.091869: Worker 0: training step 622 done (global step: 2786)
# 1598144767.110089: Worker 0: training step 623 done (global step: 2790)
# 1598144767.121673: Worker 0: training step 624 done (global step: 2794)
# 1598144767.141202: Worker 0: training step 625 done (global step: 2798)
# 1598144767.162999: Worker 0: training step 626 done (global step: 2802)
# 1598144767.182150: Worker 0: training step 627 done (global step: 2807)
# 1598144767.201749: Worker 0: training step 628 done (global step: 2810)
# 1598144767.219541: Worker 0: training step 629 done (global step: 2814)
# 1598144767.230915: Worker 0: training step 630 done (global step: 2821)
# 1598144767.248195: Worker 0: training step 631 done (global step: 2824)
# 1598144767.267463: Worker 0: training step 632 done (global step: 2828)
# 1598144767.296409: Worker 0: training step 633 done (global step: 2833)
# 1598144767.314645: Worker 0: training step 634 done (global step: 2838)
# 1598144767.333916: Worker 0: training step 635 done (global step: 2843)
# 1598144767.360526: Worker 0: training step 636 done (global step: 2845)
# 1598144767.378973: Worker 0: training step 637 done (global step: 2851)
# 1598144852.553994: Worker 0: training step 5340 done (global step: 19910)
# 1598144852.569244: Worker 0: training step 5341 done (global step: 19913)
# 1598144852.581553: Worker 0: training step 5342 done (global step: 19917)
# 1598144852.601609: Worker 0: training step 5343 done (global step: 19920)
# 1598144852.614100: Worker 0: training step 5344 done (global step: 19924)
# 1598144852.622609: Worker 0: training step 5345 done (global step: 19926)
# 1598144852.634663: Worker 0: training step 5346 done (global step: 19929)
# 1598144852.651085: Worker 0: training step 5347 done (global step: 19933)
# 1598144852.671435: Worker 0: training step 5348 done (global step: 19934)
# 1598144852.688734: Worker 0: training step 5349 done (global step: 19939)
# 1598144852.704755: Worker 0: training step 5350 done (global step: 19942)
# 1598144852.723838: Worker 0: training step 5351 done (global step: 19947)
# 1598144852.749528: Worker 0: training step 5352 done (global step: 19951)
# 1598144852.771778: Worker 0: training step 5353 done (global step: 19956)
# 1598144852.790771: Worker 0: training step 5354 done (global step: 19959)
# 1598144852.800898: Worker 0: training step 5355 done (global step: 19963)
# 1598144852.813117: Worker 0: training step 5356 done (global step: 19965)
# 1598144852.823522: Worker 0: training step 5357 done (global step: 19969)
# 1598144852.839950: Worker 0: training step 5358 done (global step: 19972)
# 1598144852.856676: Worker 0: training step 5359 done (global step: 19976)
# 1598144852.870445: Worker 0: training step 5360 done (global step: 19980)
# 1598144852.884017: Worker 0: training step 5361 done (global step: 19983)
# 1598144852.900198: Worker 0: training step 5362 done (global step: 19987)
# 1598144852.914165: Worker 0: training step 5363 done (global step: 19990)
# 1598144852.928567: Worker 0: training step 5364 done (global step: 19994)
# 1598144852.946938: Worker 0: training step 5365 done (global step: 19998)
# 1598144852.960642: Worker 0: training step 5366 done (global step: 20002)
# Training ends @ 1598144852.960698
# Training elapsed time: 98.203693 s
# After 20000 training step(s), validation cross entropy = 3462.39

# %% [markdown]
# # Launch Distributed PyTorch Job

# %%
# !cat ./distributed-training-jobs/distributed-pytorch-job.yaml
# Out:
# apiVersion: "kubeflow.org/v1"
# kind: "PyTorchJob"
# metadata:
#   name: "distributed-pytorch-job"
# spec:
#   pytorchReplicaSpecs:
#     Master:
#       replicas: 1
#       restartPolicy: OnFailure
#       template:
#         metadata:
#           annotations:
#             sidecar.istio.io/inject: "false"
#         spec:
#           containers:
#             - name: pytorch
#               image: gcr.io/kubeflow-ci/pytorch-dist-mnist_test:1.0
#               args: ["--backend", "gloo"]
#               # Comment out the below resources to use the CPU.
#               #resources:
#                 #limits:
#                   #nvidia.com/gpu: 1
#     Worker:
#       replicas: 2
#       restartPolicy: OnFailure
#       template:
#         metadata:
#           annotations:
#             sidecar.istio.io/inject: "false"
#         spec:
#           containers:
#             - name: pytorch
#               image: gcr.io/kubeflow-ci/pytorch-dist-mnist_test:1.0
#               args: ["--backend", "gloo"]
#               # Comment out the below resources to use the CPU.
#               #resources:
#                 #limits:
#                   #nvidia.com/gpu: 1

# %% [markdown]
# # Launch Distributed PyTorch Training Job

# %%
# !kubectl apply -f ./distributed-training-jobs/distributed-pytorch-job.yaml
# Out:
# pytorchjob.kubeflow.org/distributed-pytorch-job created

# %%
# !kubectl describe pytorchjob distributed-pytorch-job
# Out:
# Name:         distributed-pytorch-job
# Namespace:    anonymous
# Labels:       <none>
# Annotations:  kubectl.kubernetes.io/last-applied-configuration:
#                 {"apiVersion":"kubeflow.org/v1","kind":"PyTorchJob","metadata":{"annotations":{},"name":"distributed-pytorch-job","namespace":"anonymous"}...
# API Version:  kubeflow.org/v1
# Kind:         PyTorchJob
# Metadata:
#   Creation Timestamp:  2020-08-23T01:05:35Z
#   Generation:          1
#   Resource Version:    63151
#   Self Link:           /apis/kubeflow.org/v1/namespaces/anonymous/pytorchjobs/distributed-pytorch-job
#   UID:                 eecc655f-2da3-4e5e-b319-5859b7a6df80
# Spec:
#   Pytorch Replica Specs:
#     Master:
#       Replicas:        1
#       Restart Policy:  OnFailure
#       Template:
#         Metadata:
#           Annotations:
#             sidecar.istio.io/inject:  false
#         Spec:
#           Containers:
#             Args:
#               --backend
#               gloo
#             Image:  gcr.io/kubeflow-ci/pytorch-dist-mnist_test:1.0
#             Name:   pytorch
#     Worker:
#       Replicas:        2
#       Restart Policy:  OnFailure
#       Template:
#         Metadata:
#           Annotations:
#             sidecar.istio.io/inject:  false
#         Spec:
#           Containers:
#             Args:
#               --backend
#               gloo
#             Image:  gcr.io/kubeflow-ci/pytorch-dist-mnist_test:1.0
#             Name:   pytorch
# Status:
#   Conditions:
#     Last Transition Time:  2020-08-23T01:05:35Z
#     Last Update Time:      2020-08-23T01:05:35Z
#     Message:               PyTorchJob distributed-pytorch-job is created.
#     Reason:                PyTorchJobCreated
#     Status:                True
#     Type:                  Created
#   Replica Statuses:
#     Master:
#     Worker:
#   Start Time:  2020-08-23T01:05:35Z
# Events:
#   Type    Reason                   Age   From              Message
#   ----    ------                   ----  ----              -------
#   Normal  SuccessfulCreatePod      1s    pytorch-operator  Created pod: distributed-pytorch-job-worker-0
#   Normal  SuccessfulCreatePod      1s    pytorch-operator  Created pod: distributed-pytorch-job-worker-1
#   Normal  SuccessfulCreatePod      0s    pytorch-operator  Created pod: distributed-pytorch-job-master-0
#   Normal  SuccessfulCreateService  0s    pytorch-operator  Created service: distributed-pytorch-job-master-0

# %% [markdown]
# # Check Distributed PyTorch Training Logs
# ## _Note:  If you see an error below, just wait a bit and re-run.  You will eventually see the pod status change to `Running` or `Completed`._

# %%
# !kubectl get pod | grep distributed-pytorch-job
# Out:
# distributed-pytorch-job-master-0      0/1     ContainerCreating   0          1s
# distributed-pytorch-job-worker-0      0/1     Init:0/1            0          2s
# distributed-pytorch-job-worker-1      0/1     Init:0/1            0          2s

# %% [markdown]
# # If You See an Error Below, Wait a Few Seconds and Re-Run It

# %%
# !kubectl logs distributed-pytorch-job-master-0
# Out:
# Using distributed PyTorch with gloo backend
# Downloading http://yann.lecun.com/exdb/mnist/train-images-idx3-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/train-labels-idx1-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/t10k-images-idx3-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/t10k-labels-idx1-ubyte.gz
# Processing...
# Done!
# Train Epoch: 1 [0/60000 (0%)]	loss=2.3000
# Train Epoch: 1 [640/60000 (1%)]	loss=2.2135
# Train Epoch: 1 [1280/60000 (2%)]	loss=2.1704
# Train Epoch: 1 [1920/60000 (3%)]	loss=2.0766
# Train Epoch: 1 [2560/60000 (4%)]	loss=1.8679
# Train Epoch: 1 [3200/60000 (5%)]	loss=1.4135
# Train Epoch: 1 [3840/60000 (6%)]	loss=1.0003
# Train Epoch: 1 [4480/60000 (7%)]	loss=0.7762
# Train Epoch: 1 [5120/60000 (9%)]	loss=0.4598
# Train Epoch: 1 [5760/60000 (10%)]	loss=0.4860
# Train Epoch: 1 [6400/60000 (11%)]	loss=0.4389
# Train Epoch: 1 [7040/60000 (12%)]	loss=0.4084
# Train Epoch: 1 [7680/60000 (13%)]	loss=0.4602
# Train Epoch: 1 [8320/60000 (14%)]	loss=0.4289
# Train Epoch: 1 [8960/60000 (15%)]	loss=0.3990
# Train Epoch: 1 [9600/60000 (16%)]	loss=0.3852
# Train Epoch: 1 [10240/60000 (17%)]	loss=0.2984
# Train Epoch: 1 [10880/60000 (18%)]	loss=0.5029
# Train Epoch: 1 [11520/60000 (19%)]	loss=0.5236
# Train Epoch: 1 [12160/60000 (20%)]	loss=0.3378
# Train Epoch: 1 [12800/60000 (21%)]	loss=0.3674
# Train Epoch: 1 [13440/60000 (22%)]	loss=0.4508
# Train Epoch: 1 [14080/60000 (23%)]	loss=0.3034
# Train Epoch: 1 [14720/60000 (25%)]	loss=0.3575
# Train Epoch: 1 [15360/60000 (26%)]	loss=0.3313
# Train Epoch: 1 [16000/60000 (27%)]	loss=0.4405
# Train Epoch: 1 [16640/60000 (28%)]	loss=0.3639
# Train Epoch: 1 [17280/60000 (29%)]	loss=0.3169
# Train Epoch: 1 [17920/60000 (30%)]	loss=0.2014
# Train Epoch: 1 [18560/60000 (31%)]	loss=0.4976
# Train Epoch: 1 [19200/60000 (32%)]	loss=0.3257
# Train Epoch: 1 [19840/60000 (33%)]	loss=0.1192
# Train Epoch: 1 [20480/60000 (34%)]	loss=0.1902
# Train Epoch: 1 [21120/60000 (35%)]	loss=0.1412
# Train Epoch: 1 [21760/60000 (36%)]	loss=0.3140
# Train Epoch: 1 [22400/60000 (37%)]	loss=0.1515
# Train Epoch: 1 [23040/60000 (38%)]	loss=0.2892
# Train Epoch: 1 [23680/60000 (39%)]	loss=0.4668
# Train Epoch: 1 [24320/60000 (41%)]	loss=0.2153
# Train Epoch: 1 [24960/60000 (42%)]	loss=0.1508
# Train Epoch: 1 [25600/60000 (43%)]	loss=0.2245
# Train Epoch: 1 [26240/60000 (44%)]	loss=0.2629
# Train Epoch: 1 [26880/60000 (45%)]	loss=0.2330
# Train Epoch: 1 [27520/60000 (46%)]	loss=0.2619
# Train Epoch: 1 [28160/60000 (47%)]	loss=0.2126
# Train Epoch: 1 [28800/60000 (48%)]	loss=0.1323
# Train Epoch: 1 [29440/60000 (49%)]	loss=0.2793
# Train Epoch: 1 [30080/60000 (50%)]	loss=0.0935
# Train Epoch: 1 [30720/60000 (51%)]	loss=0.1272
# Train Epoch: 1 [31360/60000 (52%)]	loss=0.2473
# Train Epoch: 1 [32000/60000 (53%)]	loss=0.3396
# Train Epoch: 1 [32640/60000 (54%)]	loss=0.1521
# Train Epoch: 1 [33280/60000 (55%)]	loss=0.0909
# Train Epoch: 1 [33920/60000 (57%)]	loss=0.1455
# Train Epoch: 1 [34560/60000 (58%)]	loss=0.1976
# Train Epoch: 1 [35200/60000 (59%)]	loss=0.2174
# Train Epoch: 1 [35840/60000 (60%)]	loss=0.0634
# Train Epoch: 1 [36480/60000 (61%)]	loss=0.1372
# Train Epoch: 1 [37120/60000 (62%)]	loss=0.1149
# Train Epoch: 1 [37760/60000 (63%)]	loss=0.2346
# Train Epoch: 1 [38400/60000 (64%)]	loss=0.0631
